# %%
import cobra
from cobra import Model,Reaction,Metabolite
import escher
from escher import Builder
model = Model('model')
###############################################################################################################################

CO2t=Reaction('CO2t')
CO2t.name='CO2 transporter via diffusion '
CO2t.lower_bound=-1000.0
CO2t.upper_bound=1000.0

O2t=Reaction('O2t')
O2t.name='O2 transport  diffusion '
O2t.lower_bound=-1000.0
O2t.upper_bound=1000.0

NH4t=Reaction('NH4t')
NH4t.name='Ammonia reversible transport'
NH4t.lower_bound=-1000.0
NH4t.upper_bound=1000.0

H2Ot=Reaction('H2Ot')
H2Ot.name='H2O transport via diffusion'
H2Ot.lower_bound=-1000.0
H2Ot.upper_bound=1000.0

GLUin=Reaction('GLUin')
GLUin.name='Glucose import'
GLUin.lower_bound=1
GLUin.upper_bound=1

AMPin=Reaction('AMPin')
AMPin.name='AMP import'
AMPin.lower_bound=1
AMPin.upper_bound=1

HK=Reaction("HK") #Hexokinase
HK.name = "Hexokinase"
HK.lower_bound = 0.0
HK.upper_bound = 1000.0

PGI = Reaction("PGI") #Glucose 6-phosphate isomerase
PGI.name = "Glucose 6-phosphate isomerase"
PGI.lower_bound = -1000.0
PGI.upper_bound =  1000.0

PFK = Reaction("PFK")#D-Glucose exchange
PFK.name = "Phosphofructokinase"
PFK.lower_bound = 0.0
PFK.upper_bound = 1000.0

TPI = Reaction("TPI")#D-Glucose exchange
TPI.name = "Triose-phosphate isomerase"
TPI.lower_bound = -1000.0
TPI.upper_bound =  1000.0

ALD = Reaction("ALD")#D-Glucose exchange
ALD.name = "Fructose 1,6-diphosphate aldolase"
ALD.lower_bound = -1000.0
ALD.upper_bound =  1000.0

GAPDH = Reaction("GAPDH")#D-Glucose exchange
GAPDH.name = "Glyceraldehyde 3-phosphate dehydrogenase"
GAPDH.lower_bound = -1000.0
GAPDH.upper_bound =  1000.0

PGK = Reaction("PGK")#D-Glucose exchange
PGK.name = "Phosphoglycerate kinase"
PGK.lower_bound = -1000.0
PGK.upper_bound =  1000.0

PGLM = Reaction("PGLM")#D-Glucose exchange
PGLM.name = "Phosphoglycerate mutase"
PGLM.lower_bound = -1000.0
PGLM.upper_bound =  1000.0

ENO= Reaction("ENO")#D-Glucose exchange
ENO.name = "Enolase"
ENO.lower_bound = -1000.0
ENO.upper_bound =  1000.0

PK = Reaction("PK")#D-Glucose exchange
PK.name = "Pyruvate kinase"
PK.lower_bound = 0.0
PK.upper_bound = 1000.0

LDH= Reaction("LDH")#D-Glucose exchange
LDH.name = "Lactate dehydrogenase"
LDH.lower_bound = -1000
LDH.upper_bound =  1000

AMP_ = Reaction("AMP_")#D-Glucose exchange
AMP_.name = "AMP export"
AMP_.lower_bound = 0
AMP_.upper_bound = 1000

APK = Reaction("APK")#D-Glucose exchange
APK.name = "Adenylate kinase"
APK.lower_bound = -1000
APK.upper_bound =  1000

PYR_ = Reaction("PYR_")#D-Glucose exchange
PYR_.name = "Pyruvate exchange"
PYR_.lower_bound = -1000
PYR_.upper_bound = 1000

LAC_ = Reaction("LAC_")#D-Glucose exchange
LAC_.name = "Lactate exchange"
LAC_.lower_bound = -1000
LAC_.upper_bound = 1000

ATP_ = Reaction("ATP_")#D-Glucose exchange
ATP_.name = "ATP hydrolysis"
ATP_.lower_bound = 0
ATP_.upper_bound = 1000

NADH_ = Reaction("NADH_")#D-Glucose exchange
NADH_.name = "NADH oxidation"
NADH_.lower_bound = 0
NADH_.upper_bound = 1000

H2O_ = Reaction("H2O_")#D-Glucose exchange
H2O_.name = "Water exchange"
H2O_.lower_bound = -1000
H2O_.upper_bound = 1000

H_ = Reaction("H_")#D-Glucose exchange
H_.name = "Proton exchange"
H_.lower_bound = -1000
H_.upper_bound = 1000

GLCpts=Reaction('GLCpts')
GLCpts.name='GLCpts'
GLCpts.lower_bound = 0.0
GLCpts.upper_bound = 1000

######################################################### PP Pathway ###########################################################
G6PDH = Reaction("G6PDH")#G6P dehydrogenasee
G6PDH.name = "G6P dehydrogenasee"
G6PDH.lower_bound = 0
G6PDH.upper_bound = 1000

PGLase = Reaction("PGLase")#6-Phosphogluconolactonase
PGLase.name = "6-Phosphogluconolactonase"
PGLase.lower_bound = 0
PGLase.upper_bound = 1000

GL6PDH = Reaction("GL6PDH")#GO6P dehydrogenase
GL6PDH.name = "GO6P dehydrogenase"
GL6PDH.lower_bound = 0
GL6PDH.upper_bound = 1000

R5PE = Reaction("R5PE")#X5P epimerase
R5PE.name = "X5P epimerase"
R5PE.lower_bound = -1000
R5PE.upper_bound =  1000

R5PI = Reaction("R5PI")#R5P isomerase
R5PI.name = "R5P isomerase"
R5PI.lower_bound = -1000
R5PI.upper_bound =  1000

TKI = Reaction("TKI")#Transketolase I
TKI.name = "Transketolase I"
TKI.lower_bound = -1000
TKI.upper_bound =  1000

TKII = Reaction("TKII")#Transketolase II
TKII.name = "Transketolase II"
TKII.lower_bound = -1000
TKII.upper_bound =  1000

TALA = Reaction("TALA")#Transaldolase
TALA.name = "Transaldolase"
TALA.lower_bound = -1000
TALA.upper_bound =  1000

GSSGR = Reaction("GSSGR")#Glutathione reductase
GSSGR.name = "Glutathione reductase"
GSSGR.lower_bound = -1000
GSSGR.upper_bound =  1000

GSHR = Reaction("GSHR")#Glutathione oxidase
GSHR.name = "Glutathione oxidase"
GSHR.lower_bound = -1000
GSHR.upper_bound =  1000

CO2_exch = Reaction("CO2_exch")#freely exchanging CO2
CO2_exch.name = "freely exchanging CO2"
CO2_exch.lower_bound = 0
CO2_exch.upper_bound = 1000

RPE = Reaction("RPE")
RPE.name = "Ribulose 5-phosphate 3-epimerase"
RPE.lower_bound = -1000.0
RPE.upper_bound =  1000


######################################################## Acetate_Fermentaion ###################################################
PTAr=Reaction("PTAr")
PTAr.name='Phosphotransacetylase'
PTAr.lower_bound=-1000
PTAr.upper_bound=1000

ACK=Reaction("ACK")
ACK.name='Acetate kinase'
ACK.lower_bound=-1000
ACK.upper_bound=1000

Acetate_EX=Reaction('Acetate_exchange')
Acetate_EX.name='Acetate exchange'
Acetate_EX.lower_bound=0
Acetate_EX.upper_bound=1000

PDH=Reaction('PDH')
PDH.name='Pyruvate dehydrogenase'
PDH.lower_bound=0
PDH.upper_bound=1000

############################################### Citric Acid Cycle (TCA Cycle) ##################################################
CS=Reaction('CS') #Citrate synthase 
CS.name='Citrate synthase'
CS.lower_bound=-1000.0
CS.upper_bound=1000.0 

ACONTa=Reaction('ACONTa') #Aconitase (half-reaction A, Citrate hydro-lyase)
ACONTa.name='Aconitase_1'
ACONTa.lower_bound=-1000.0
ACONTa.upper_bound=1000.0

ACONTb=Reaction('ACONTb') #Aconitase (half-reaction A, Citrate hydro-lyase)
ACONTb.name='Aconitase_2'
ACONTb.lower_bound=-1000.0
ACONTb.upper_bound=1000.0

ICDHyr=Reaction('ICDHyr') #Isocitrate dehydrogenase (NADP)
ICDHyr.name='Isocitrate dehydrogenase (NADP)'
ICDHyr.lower_bound=-1000.0
ICDHyr.upper_bound=1000.0

AKGDH=Reaction('AKGDH') #α-ketoglutarate dehydrogenase
AKGDH.name='α-ketoglutarate dehydrogenase'
AKGDH.lower_bound=-1000.0
AKGDH.upper_bound=1000.0

SUCOAS=Reaction('SUCOAS') #Succinyl-CoA synthetase (ADP-forming)
SUCOAS.name='Succinyl-CoA synthetase (ADP-forming)'
SUCOAS.lower_bound=-1000.0
SUCOAS.upper_bound=1000.0

SUCDi=Reaction('SUCDi') #Succinate dehydrogenase (irreversible)
SUCDi.name='Succinate dehydrogenase (irreversible)'
SUCDi.lower_bound=-1000.0
SUCDi.upper_bound=1000.0

FUM=Reaction('FUM') #Fumarase
FUM.name='Fumarase'
FUM.lower_bound=-1000.0
FUM.upper_bound=1000.0

MDH=Reaction('MDH') #Malate dehydrogenase
MDH.name='Malate dehydrogenase'
MDH.lower_bound=-1000.0
MDH.upper_bound=1000.0

PIt2r=Reaction('PIt2r')
PIt2r.name='Phosphate reversible transport via symport'
PIt2r.lower_bound=-1000.0
PIt2r.upper_bound=1000.0

###############################################################################################################################

                                       ############# Oxidative Phoso Start #############
    
# 43th reaction  -----> NADHQ                    NADH + Q + 5H → NAD + QH2 + 4H 
        
NADHQ=Reaction('NADHQ')
NADHQ.name='NADH-coenzyme Q oxidoreductase (complex I)'
NADHQ.lower_bound = 0
NADHQ.upper_bound = 1000

# 44th reaction  -----> SUCCQ                    Succinate + Q → QH2 + Fumarate

SUCCQ=Reaction('SUCCQ')
SUCCQ.name='Succinate-Q oxidoreductase (complex II)'
SUCCQ.lower_bound = 0
SUCCQ.upper_bound = 1000

# 45th reaction  -----> QUIN                      QH2 + 2Fe3+  → Q + 2Fe2+ + 2H  

QUIN=Reaction('QUIN')
QUIN.name='Quinol--cytochrome-c reductase (complex III)'
QUIN.lower_bound = 0
QUIN.upper_bound = 1000

# 46th reaction  -----> CYTO                       8H + 4Fe2+ + O2 → 2H2O + 4Fe3+ + 4H 

CYTO=Reaction('CYTO')
CYTO.name='Cytochrome-c oxidase (complex IV)'
CYTO.lower_bound = 0
CYTO.upper_bound = 1000

# 47th reaction  -----> ATPase                     ATP + 4H + H2O ↔ ADP + 5H + Pi 

ATPase=Reaction('ATPase')
ATPase.name='H(+)-transporting two-sector ATPase'
ATPase.lower_bound = -1000
ATPase.upper_bound =  1000

# 48th reaction  -----> Phos                        Pi + H2O ↔ H + 2Pi 

Phos=Reaction('Phos')
Phos.name='Inorganic diphosphatase'
Phos.lower_bound =  0
Phos.upper_bound =  1000

# 49th reaction  -----> ATPPoly                     Pi + ATP ↔ ADP + 2Pi

ATPPoly=Reaction('ATPPoly')
ATPPoly.name='ATP-polyphosphate phosphotransferase'
ATPPoly.lower_bound = -1000
ATPPoly.upper_bound =  1000
################################################################################################################################
Biomass=Reaction('Biomass')
Biomass.name='Biomass Objective Function with GAM'
Biomass.lower_bound = 0
Biomass.upper_bound = 1000

EX_h_e=Reaction('EX_h_e')
EX_h_e.name='EX_h_e'
EX_h_e.lower_bound = -1000.0
EX_h_e.upper_bound = 1000

EX_glc__D_e=Reaction('EX_glc__D_e')
EX_glc__D_e.name='D-Glucose exchange'
EX_glc__D_e.lower_bound = 0
EX_glc__D_e.upper_bound = 1000

EX_nh4_e=Reaction('EX_nh4_e')
EX_nh4_e.name='Ammonia exchange'
EX_nh4_e.lower_bound = -1000.0
EX_nh4_e.upper_bound = 1000

EX_pi_e=Reaction('EX_pi_e')
EX_pi_e.name='Phosphate exchange'
EX_pi_e.lower_bound = -1000.0
EX_pi_e.upper_bound = 1000

GLNS=Reaction('GLNS')
GLNS.name='Glutamine synthetase'
GLNS.lower_bound = 0.0
GLNS.upper_bound = 1000

GLUDy=Reaction('GLUDy')
GLUDy.name='Glutamate dehydrogenase (NADP)'
GLUDy.lower_bound = -1000.0
GLUDy.upper_bound = 1000

PPC=Reaction('PPC')
PPC.name='Phosphoenolpyruvate carboxylase'
PPC.lower_bound = 0.0
PPC.upper_bound = 1000

# %%
Glc = Metabolite(
        "glc",
        formula = "C6H12O6",
        name = "D-Glucose",
        compartment = 'e'
)

G6p = Metabolite(
        "g6p_c",
        formula = "C6H11O9P",
        name = "D-Glucose 6-phosphate",
        compartment = 'c'
)

F6p = Metabolite(
        "f6p_c",
        formula = "C6H11O9P",
        name = "D-Fructose 6-phosphate",
        compartment = 'c'
)

Fdp = Metabolite(
        "fdp_c",
        formula = "C6H10O12P2",
        name = "D-Fructose 1,6-bisphosphate",
        compartment = 'c'
)

Dhap = Metabolite(
        "dhap_c",
        formula = "C3H5O6P",
        name = "Dihydroxyacetone phosphate",
        compartment = 'c'
)

G3p = Metabolite(
        "g3p_c",
        formula = "C3H5O6P",
        name = "Glyceraldehyde 3-phosphate",
        compartment = 'c'
)

Dpg13 = Metabolite(
        "13dpg_c",
        formula = "C3H4O10P2",
        name = "3-Phospho-D-glyceroyl phosphate",
        compartment = 'c'
)

Pg3 = Metabolite(
        "3pg_c",
        formula = "C3H4O7P",
        name = "3-Phospho-D-glycerate",
        compartment = 'c'
)

Pg2 = Metabolite(
        "2pg_c",
        formula = "C3H4O7P",
        name = "D-Glycerate 2-phosphate",
        compartment = 'c'
)

Pep = Metabolite(
        "pep_c",
        formula = "C3H2O6P",
        name = "Phosphoenolpyruvate",
        compartment = 'c'
)

Pyr = Metabolite(
        "pyr_c",
        formula = "C3H3O3",
        name = "Pyruvate",
        compartment = 'c'
)

Lac = Metabolite(
        "lac__D_c",
        formula = "C3H5O3",
        name = "D-Lactate",
        compartment = 'c'
)

NAD=Metabolite(
        'NAD',
        name= "Nicotinamide adenine dinucleotide (oxidized)",
        formula="C21H27N7O14P2",
        compartment='c'
)

NADH=Metabolite(
        'NADH',
        name= "Nicotinamide adenine dinucleotide (reduced)",
        formula="C21H27N7O14P2",
        compartment='c'
)

AMP=Metabolite(
        'AMP',
        name= "Adenosine mono-phosphate",
        formula="C10H14N5O7P",
        compartment='c'
)

ADP=Metabolite(
        'ADP',
        name= "Adenosine Di-phosphate",
        formula="C10H15N5O10P2",
        compartment='c'
)

ATP=Metabolite(
        'ATP',
        name= "Adenosine tri-phosphate",
        formula="C10H16N5O13P3",
        compartment='c'
)

Pi=Metabolite(
        'Pi',
        name= "Inorganic phosphate",
        formula="PO4",
        compartment='c'
)

H=Metabolite(
        'H',
        formula="H",
        name= "Proton",
        compartment='c'
)

H2O=Metabolite(
        'H2O',
        name= "Water",
        formula="H2O",
        compartment='c'
)

Amp = Metabolite(
        "amp_c",
        formula = "C10H12N5O7P",
        name = "AMP C10H12N5O7P",
        compartment = 'c'
)

nh4_e = Metabolite(
        "nh4_e",
        formula = "H4N",
        name = "Ammonium",
        compartment = 'e'
)

######################################################### PP Pathway ###########################################################
GL6P = Metabolite(
        "GL6P",
        formula = "C6H11O9P",
        name = "6-Phosphogluconolactone",
        compartment = 'c'
)

GO6P = Metabolite(
        "GO6P",
        formula = "C6H13O10P",
        name = "6-Phosphogluconic acid",
        compartment = 'c'
)

NADP = Metabolite(
        "NADP",
        formula = "C21H29N7O17P3",
        name = "Nicotinamide adenine dinucleotide phosphate",
        compartment = 'c'
)

NADPH = Metabolite(
        "NADPH",
        formula = "C21H29N7O17P3",
        name = "Nicotinamide adenine dinucleotide phosphate",
        compartment = 'c'
)

RU5P = Metabolite(
        "RU5P",
        formula = "C5H11O8P",
        name = "Ribulose 5-phosphate",
        compartment = 'c'
)

X5P = Metabolite(
        "X5P",
        formula = "C5H11O8P",
        name = "Xylulose 5-phosphate",
        compartment = 'c'
)

R5P = Metabolite(
        "R5P",
        formula = "C5H11O8P",
        name = "Ribose 5-phosphate",
        compartment = 'c'
)

S7P = Metabolite(
        "S7P",
        formula = "C7H15O10P",
        name = "Sedoheptulose 7-phosphate",
        compartment = 'c'
)

E4P = Metabolite(
        "E4P",
        formula = "C4H9O7P",
        name = "Erythrose 4-phosphate",
        compartment = 'c'
)

GSSG = Metabolite(
        "GSSG",
        formula = "C20H32N6O12S2",
        name = "Glutathione disulfide",
        compartment = 'c'
)
GSH = Metabolite(
        "GSH",
        formula = "C10H17N3O6S",
        name = "Glutathione",
        compartment = 'c'
)

CO2 = Metabolite(
        'co2',
        name="CO2 CO2",
        formula="CO2",
        compartment='c'
)

######################################################## Acetate_Fermentaion #################################################

actp=Metabolite(
        'Acetyl_phosphate',
        name= "Acetyl phosphate",
        formula="C2H3O5P",
        compartment='c'
)

ac=Metabolite(
        'Acetate',
        name= "Acetate",
        formula="C2H3O2",
        compartment='c'
)

CoA=Metabolite(
        'CoA',
        name= "CoA",
        formula="C21H36N7O16P3S",
        compartment='c'
)

Acetyl_CoA=Metabolite(
        'Acetyl_CoA',
        name= "Acetyl CoA",
        formula="C23H38N7O17P3S",
        compartment='c'
)

##############################################################################################################################

Oxa = Metabolite(
        "oxa",
        formula = "C4H2O5",
        name = "Oxaloacetate",
        compartment = 'c'
)

CIT = Metabolite(
        'CIT',
        name="Citrate",
        formula="C6H5O7",
        compartment='c'
)

cis_acon = Metabolite(
        'acon_C_c',
        name="Cis-Aconitate",
        formula="C6H3O6",
        compartment='c'
)

ISC = Metabolite(
        'isc',
        name="Isocitrate",
        formula="C6H8O7",
        compartment='c'
)

AKG = Metabolite(
        'akg',
        name="2-Oxoglutarate",
        formula="C5H4O5",
        compartment='c'
)

SUCCOA = Metabolite(
        'succoa',
        name="Succinyl-CoA",
        formula="C25H35N7O19P3S",
        compartment='c'
)

ATP= Metabolite(
        'ATP',
        name="ATP C10H12N5O13P3",
        formula="C10H12N5O13P3",
        compartment='c'
)

ADP = Metabolite(
        'ADP',
        name="ADP C10H12N5O10P2",
        formula="C10H12N5O10P2",
        compartment='c'
)

SUCC = Metabolite(
        'succ',
        name="Succinate",
        formula="C4H4O4",
        compartment='c'
)

FAD = Metabolite(
        'fad',
        name="FAD C27H33P2N9O15",
        formula="C27H33P2N9O15",
        compartment='c'
)

FADH2 = Metabolite(
        'fadh2',
        name="FADH2 C27H35N9O15P2",
        formula="C27H35N9O15P2",
        compartment='c'
)

FUMA = Metabolite(
        'fuma',
        name="Fumarate",
        formula="C4H2O4",
        compartment='c'
)

MAL = Metabolite(
        'mal',
        name="L-Malate",
        formula="C4H4O5",
        compartment='c'
)
Q = Metabolite(
        'Q',
        formula='C9H10O4(C5H8)n',
        name='a ubiquinone',
        compartment='c'
)
QH2 = Metabolite(
        'QH2',
        formula='C9H12O4(C5H8)n',
        name='a ubiquinol',
        compartment='c'
)
Fe3 = Metabolite(
        'Fe3',
        formula='Fe',
        name='Fe(III)-[cytochrome c]',
        compartment='c'
)
Fe2 = Metabolite(
        'Fe2',
        formula='Fe',
        name='Fe(II)-[cytochrome c]',
        compartment='c'
)

O2 = Metabolite(
        'O2',
        formula='O2',
        name='O2',
        compartment='c'
)

diphosphate = Metabolite(
        'diphosphate',
        formula='',
        name='diphosphate',
        compartment='c'
)

gln__L_c = Metabolite(
        'gln__L_c',
        formula='C5H10N2O3',
        name='L-Glutamine',
        compartment='c'
)
glu__L_c = Metabolite(
        'glu__L_c',
        formula='C5H8NO4',
        name='L-Glutamate',
        compartment='c'
)

nh4_c = Metabolite(
        'nh4_c',
        formula='H4N',
        name='Ammonium',
        compartment='c'
)

# %%
AMPin.add_metabolites({
        AMP:1
})

GLUin.add_metabolites({
        Glc:1
})

HK.add_metabolites({
        Glc:-1,
        ATP:-1,
        G6p:1,
        ADP:1,
        H:1
})

PGI.add_metabolites({
        G6p:-1,
        F6p:1
})

PFK.add_metabolites({
        F6p:-1,
        ATP:-1,
        Fdp:1,
        ADP:1,
        H:1
})

TPI.add_metabolites({
        Dhap:-1,
        G3p:1
})

ALD.add_metabolites({
        Fdp:-1,
        Dhap:1,
        G3p:1
})

GAPDH.add_metabolites({
        G3p:-1,
        NAD:-1,
        Pi:-1,
        Dpg13:1,
        NADH:1,
        H:1
})

PGK.add_metabolites({
        Dpg13:-1,
        ADP:-1,
        Pg3:1,
        ATP:1
})

PGLM.add_metabolites({
        Pg3:-1,
        Pg2:1
})

ENO.add_metabolites({
        Pg2:-1,
        Pep:1,
        H2O:1
})

PK.add_metabolites({
        Pep:-1,
        ADP:-1,
        H:-1,
        Pyr:1,
        ATP:1
})

LDH.add_metabolites({
        Pyr:-1,
        NADH:-1,
        H:-1,
        Lac:1,
        NAD:1
})

APK.add_metabolites({
        ADP:-2,
        AMP:1,
        ATP:1
})

AMP_.add_metabolites({
        AMP:-1
})

LAC_.add_metabolites({
        Lac:-1
})

PYR_.add_metabolites({
        Pyr:-1
})

ATP_.add_metabolites({
        ATP:-1,
        H2O:-1,
        ADP:1,
        Pi:1,
        H:1
})

NADH_.add_metabolites({
        NADH:-1,
        NAD:1,
        H:1
})

H2O_.add_metabolites({
        H2O:-1
})

H_.add_metabolites({
        H:-1
})

CO2t.add_metabolites({
        CO2:-1,
        CO2:1

})

EX_glc__D_e.add_metabolites({
        Glc:-1,
})

######################################################### PP Pathway ###########################################################

G6PDH.add_metabolites({
        G6p: -1,
        NADP: -1,
        GL6P: 1,
        NADPH: 1,
        H:1
}) 

PGLase.add_metabolites({
    GL6P: -1,
    H2O: -1,
    GO6P: 1,
    H:1
}) 

GL6PDH.add_metabolites({
        GO6P: -1,
        NADP: -1,
        RU5P: 1,
        NADPH:1,
        CO2:1
})

R5PE.add_metabolites({
        RU5P: -1,
        X5P: 1
}) 

R5PI.add_metabolites({
        RU5P: -1,
        R5P: 1
})

TKI.add_metabolites({
        X5P: -1,
        R5P: -1,
        S7P: 1,
        G3p: 1
})

TKII.add_metabolites({
        X5P: -1,
        E4P: -1,
        F6p: 1,
        G3p: 1
})

TALA.add_metabolites({ 
        S7P: -1,
        G3p: -1,
        E4P: 1,
        F6p: 1
})

GSSGR.add_metabolites({ 
        GSSG: -1,
        NADPH: -1,
        H: -1,
        GSH: 2,
        NADP: 1
})

GSHR.add_metabolites({ 
        GSH: -2,
        GSSG: 1,
        H:    2 
})

CO2_exch.add_metabolites({
        CO2: -1

})

######################################################## Acetate_Fermentaion #################################################
PTAr.add_metabolites({
        Acetyl_CoA:-1,
        Pi:-1,
        CoA:-1,
        actp:1
})

ACK.add_metabolites({
        actp:-1,
        ADP:-1,
        ac:1,
        ATP:1
})

Acetate_EX.add_metabolites({
        ac:-1
})

PDH.add_metabolites({
        Pyr:-1,
        NAD:-1,
        CoA:-1,
        Acetyl_CoA:1,
        CO2:1,
        NADH:1
})
##############################################################################################################################
CS.add_metabolites({
        Acetyl_CoA:-1,
        CIT:1,
        CoA:1,
        H2O:-1,
        H:1,
        Oxa:-1
    
})

ACONTa.add_metabolites({
        cis_acon:1,
        CIT:-1,
        H2O:1
})

ACONTb.add_metabolites({
        cis_acon:-1,
        ISC:1,
        H2O:-1
})

ICDHyr.add_metabolites({
        AKG:1,
        ISC:-1,
        CO2:1,
        NAD:-1,
        NADH:1   
})

AKGDH.add_metabolites({
        AKG:-1,
        SUCCOA:1,
        CO2:1,
        CoA:-1,
        NAD:-1,
        NADH:1  
})

SUCOAS.add_metabolites({
        ADP:1,
        ATP:-1,
        CoA:-1,
        Pi:1,
        SUCC:-1,
        SUCCOA:1
})

SUCDi.add_metabolites({
        SUCC:-1,
        FUMA:1,
        FAD:-1,
        FADH2:1
})

FUM.add_metabolites({
        FUMA:-1,
        H2O:-1,
        MAL:1
})

MDH.add_metabolites({
        MAL:-1,
        Oxa:1,
        NAD:-1,
        NADH:1,
        H:1
})
##############################################################################################################################
NADHQ.add_metabolites({
        NADH:-1,
        Q:-1,
        H:3.0,
        NAD:1,
        QH2:1,
        H:-4.0
})

SUCCQ.add_metabolites({
        SUCC:-1,
        Q:-1,
        FUMA:1,
        QH2:1
})

QUIN.add_metabolites({
        QH2:-1,
        Fe3:-2,
        Q:1,
        Fe2:2,
        H:2
})

CYTO.add_metabolites({
        QH2:-1.0,
        H:-2,
        O2:-1,
        Q:1.0,
        H:2,
        H2O:1.0
})

ATPase.add_metabolites({
        ATP:1,
        H:-4,
        H2O:1,
        ADP:-1,
        H:3,
        Pi:-1
})            
Phos.add_metabolites({
        diphosphate:-1,
        H2O:-1,
        H:1,
        Pi:2
})
ATPPoly.add_metabolites({
        Pi:-1,
        ATP:-1,
        Pi:2,
        ADP:1
})

EX_h_e.add_metabolites({
        H:-1
})

EX_nh4_e.add_metabolites({
        nh4_c:-1
})

EX_pi_e.add_metabolites({
       Pi:-1
})

GLNS.add_metabolites({
        ATP:-1.0,
        ADP:-1.0,
        gln__L_c:1.0,
        glu__L_c:-1.0,
        H:1.0,
        nh4_c:-1.0,
        Pi:1.0
})

GLUDy.add_metabolites({
        AKG:1.0,
        glu__L_c:-1.0,
        H2O:-1.0,
        H:1.0,
        NADP:-1.0,
        NADPH:1.0,
        nh4_c:1.0
})

NH4t.add_metabolites({
        nh4_c:-1.0

})

O2t.add_metabolites({
        O2:1.0,
        O2:-1.0

})

PIt2r.add_metabolites({
        H:1.0,
        H:-1.0,
        Pi:1.0,
        Pi:-1.0

})

PPC.add_metabolites({
CO2:-1.0,
H2O:-1.0,
H:1.0,
Oxa:1.0,
Pep:-1.0,
Pi:1.0

})


###############################################################################################################################
Biomass.add_metabolites({
        Pg3:-1.496,ATP:-59.81,E4P:-0.361,Acetyl_CoA:-3.7478,
        F6p:-0.0709,G3p:-0.129,G6p:-0.205,H2O:-59.81,Oxa:-1.7867,Pyr:-2.8328,
        Pep:-0.5191,R5P:-0.8977,NAD:-3.547,NADPH:-13.0279,gln__L_c:-0.2557,glu__L_c:-4.9414,
        CoA:3.7478,ADP:59.81,Pi:59.81,AKG:4.1182,NADP:13.0279,
        NADH:3.547,H:59.81
})

# %%
model.add_reactions([HK,PGI,PFK,TPI,ALD,GAPDH,PGK,PGLM,
       ENO,PK,LDH,AMP_,APK,PYR_,LAC_,ATP_,NADH_,GLUin,AMPin,H_,H2O_,G6PDH,PGLase,GL6PDH,R5PE,R5PI,TKI,TKII,TALA,GSSGR,GSHR,CO2_exch,PTAr,ACK,Acetate_EX,PDH,
       CS, ACONTa, ACONTb, ICDHyr, AKGDH, SUCOAS, SUCDi, FUM, MDH,O2t,NH4t,H2Ot,GLCpts,RPE,PIt2r,EX_h_e,EX_glc__D_e,EX_nh4_e,
                     EX_pi_e,GLNS,GLUDy,PPC,NADHQ,SUCCQ,QUIN,CYTO,ATPase,Phos,ATPPoly,Biomass])

# %%
model.objective='Biomass'

# %%
model.optimize().fluxes
# Out:
# HK          1.000000
# PGI         0.945616
# PFK         0.736119
# TPI         0.736119
# ALD         0.736119
#              ...
# CYTO        5.834408
# ATPase      0.000000
# Phos        0.000000
# ATPPoly   -16.511659
# Biomass     0.265287
# Name: fluxes, Length: 66, dtype: float64

# %%
model.optimize()
# Out:
# <Solution 0.265 at 0x2938461d2b0>
